# %%
from sklearn.cluster import AgglomerativteClustering
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /tmp/ipykernel_11392/2423959477.py in <cell line: 0>()
# ----> 1 from sklearn.cluster import AgglomerativteClustering
#
# ImportError: cannot import name 'AgglomerativteClustering' from 'sklearn.cluster' (/usr/local/lib/python3.13/dist-packages/sklearn/cluster/__init__.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
